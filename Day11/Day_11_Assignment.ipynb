# %% [markdown]
# ### Assignment : Identify co-rrelation between Attrition and other variables

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
from sklearn import preprocessing


dataset = pd.read_csv('general_data.csv')
dataset
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
dataset1 = dataset.dropna()
dataset1
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4404   29        No      Travel_Rarely                   Sales
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
label_encoder = preprocessing.LabelEncoder()
dataset1['Attrition'] = label_encoder.fit_transform(dataset1['Attrition'])
dataset1
# Out:
# /home/hamisi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       Age  Attrition     BusinessTravel              Department  \
# 0      51          0      Travel_Rarely                   Sales
# 1      31          1  Travel_Frequently  Research & Development
# 2      32          0  Travel_Frequently  Research & Development
# 3      38          0         Non-Travel  Research & Development
# 4      32          0      Travel_Rarely  Research & Development
# ...   ...        ...                ...                     ...
# 4404   29          0      Travel_Rarely                   Sales
# 4405   42          0      Travel_Rarely  Research & Development
# ...

# %%
#Between Attrition and Age
#Partial correlation since its between categorical and continuos variables

H0 = 'There is no signifucant correlation between Attrition and Age'
HA = 'There is significant correlation between Attrition and Age'

stats,p = pearsonr(dataset1.Attrition,dataset1.Age)
print(stats,p)

if p > 0.05:
    print(H0)
else:
    print(HA)
    if stats < 0:
        print('Negative correlation')
    elif statsts > 0:
        print('Positive correlation')
    
plt.scatter(dataset1.Attrition,dataset1.Age)
# Out:
# -0.1583986795409671 5.1265982193780794e-26
# There is significant correlation between Attrition and Age
# Negative correlation

# %%
#Between Attrition and DistancefromHome
#Partial correlation since its between categorical and continuos variables

H0 = 'There is no signifucant correlation between Attrition and DistanceFromHome'
HA = 'There is significant correlation between Attrition and DistanceFromHome'

stats,p = pearsonr(dataset1.Attrition,dataset1.DistanceFromHome)
print(stats,p)

if p > 0.05:
    print(H0)
else:
    print(HA)
    if stats < 0:
        print('Negative correlation')
    elif statsts > 0:
        print('Positive correlation')
        
plt.scatter(dataset1.Attrition,dataset1.DistanceFromHome)
# Out:
# -0.009448638515156246 0.5317715668019558
# There is no signifucant correlation between Attrition and DistanceFromHome

# %%
#Between Attrition and MonthlyIncome
#Partial correlation since its between categorical and continuos variables

H0 = 'There is no signifucant correlation between Attrition and MonthlyIncome'
HA = 'There is significant correlation between Attrition and MonthlyIncome'

stats,p = pearsonr(dataset1.Attrition,dataset1.MonthlyIncome)
print(stats,p)

if p > 0.05:
    print(H0)
else:
    print(HA)
    if stats < 0:
        print('Negative correlation')
    elif statsts > 0:
        print('Positive correlation')

plt.scatter(dataset1.Attrition,dataset1.MonthlyIncome)
# Out:
# -0.03016029380846066 0.045890862744719166
# There is significant correlation between Attrition and MonthlyIncome
# Negative correlation
